# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import warnings
import scipy
import lightgbm as lgb
import xgboost as xgb
import sys
import os
import sklearn as skl
#from pycaret.regression import *
warnings.filterwarnings(action='ignore')
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

import numpy as np
import pandas as pd
import sklearn
import os
import seaborn as sns
from sklearn.model_selection import train_test_split

from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import random
np.random.seed(34)
print("Tensorflow version: ", tf.__version__)
print("Numpy version: ", np.__version__)
print("Pandas version: ", pd.__version__)
print("Scikit-learn version: ", sklearn.__version__)
# Out:
# Tensorflow version:  2.12.0
# Numpy version:  1.22.4
# Pandas version:  1.4.4
# Scikit-learn version:  1.2.2

# %% [markdown]
# # 데이터 로드, type별 분리

# %%
train_data  = pd.read_csv('/content/drive/MyDrive/이상탐지/train_data.csv')

# %%
test_data  = pd.read_csv('/content/drive/MyDrive/이상탐지/test_data.csv')

# %%
test_type_0 = test_data[test_data["type"] == 0]
test_type_1 = test_data[test_data["type"] == 1]
test_type_2 = test_data[test_data["type"] == 2]
test_type_3 = test_data[test_data["type"] == 3]
test_type_4 = test_data[test_data["type"] == 4]
test_type_5 = test_data[test_data["type"] == 5]
test_type_6 = test_data[test_data["type"] == 6]
test_type_7 = test_data[test_data["type"] == 7]

# %%
train_type_0 = train_data[train_data["type"] == 0]
train_type_1 = train_data[train_data["type"] == 1]
train_type_2 = train_data[train_data["type"] == 2]
train_type_3 = train_data[train_data["type"] == 3]
train_type_4 = train_data[train_data["type"] == 4]
train_type_5 = train_data[train_data["type"] == 5]
train_type_6 = train_data[train_data["type"] == 6]
train_type_7 = train_data[train_data["type"] == 7]

# %%
train_type_0 = train_type_0[["air_inflow","motor_rpm","motor_temp","motor_current","air_end_temp","motor_vibe","out_pressure"]]
test_type_0 = test_type_0[["air_inflow","motor_rpm","motor_temp","motor_current","air_end_temp","motor_vibe","out_pressure"]]

train_type_1 = train_type_1[["air_inflow","motor_rpm","motor_temp","motor_current","air_end_temp","motor_vibe","out_pressure"]]
test_type_1 = test_type_1[["air_inflow","motor_rpm","motor_temp","motor_current","air_end_temp","motor_vibe","out_pressure"]]

train_type_2 = train_type_2[["air_inflow","motor_rpm","motor_temp","motor_current","air_end_temp","motor_vibe","out_pressure"]]
test_type_2 = test_type_2[["air_inflow","motor_rpm","motor_temp","motor_current","air_end_temp","motor_vibe","out_pressure"]]

train_type_3 = train_type_3[["air_inflow","motor_rpm","motor_temp","motor_current","air_end_temp","motor_vibe","out_pressure"]]
test_type_3 = test_type_3[["air_inflow","motor_rpm","motor_temp","motor_current","air_end_temp","motor_vibe","out_pressure"]]

train_type_4 = train_type_4[["air_inflow","motor_rpm","motor_temp","motor_current","air_end_temp","motor_vibe","out_pressure"]]
test_type_4 = test_type_4[["air_inflow","motor_rpm","motor_temp","motor_current","air_end_temp","motor_vibe","out_pressure"]]

train_type_5 = train_type_5[["air_inflow","motor_rpm","motor_temp","motor_current","air_end_temp","motor_vibe","out_pressure"]]
test_type_5 = test_type_5[["air_inflow","motor_rpm","motor_temp","motor_current","air_end_temp","motor_vibe","out_pressure"]]

train_type_6 = train_type_6[["air_inflow","motor_rpm","motor_temp","motor_current","air_end_temp","motor_vibe","out_pressure"]]
test_type_6 = test_type_6[["air_inflow","motor_rpm","motor_temp","motor_current","air_end_temp","motor_vibe","out_pressure"]]

train_type_7 = train_type_7[["air_inflow","motor_rpm","motor_temp","motor_current","air_end_temp","motor_vibe","out_pressure"]]
test_type_7 = test_type_7[["air_inflow","motor_rpm","motor_temp","motor_current","air_end_temp","motor_vibe","out_pressure"]]

# %%
col_names = train_type_0.columns

# %%
scaler = MinMaxScaler()

# %% [markdown]
# # 변수 생성(컬럼들 끼리의 나눗셈)

# %%
col_names = col_names[:-1]
num_cols = len(col_names)

for i in range(num_cols):
    for j in range(i+1, num_cols):
        col_name = f"{col_names[i]}/{col_names[j]}"
        train_type_0[col_name] = train_type_0.iloc[:, i] / train_type_0.iloc[:, j]
        train_type_0[col_name] = train_type_0[col_name].abs()


num_cols = len(col_names)

for i in range(num_cols):
    for j in range(i+1, num_cols):
        col_name = f"{col_names[i]}/{col_names[j]}"
        train_type_1[col_name] = train_type_1.iloc[:, i] / train_type_1.iloc[:, j]
        train_type_1[col_name] = train_type_1[col_name].abs()


num_cols = len(col_names)

for i in range(num_cols):
    for j in range(i+1, num_cols):
        col_name = f"{col_names[i]}/{col_names[j]}"
        train_type_2[col_name] = train_type_2.iloc[:, i] / train_type_2.iloc[:, j]
        train_type_2[col_name] = train_type_2[col_name].abs()


num_cols = len(col_names)

for i in range(num_cols):
    for j in range(i+1, num_cols):
        col_name = f"{col_names[i]}/{col_names[j]}"
        train_type_3[col_name] = train_type_3.iloc[:, i] / train_type_3.iloc[:, j] 
        train_type_3[col_name] = train_type_3[col_name].abs()


num_cols = len(col_names)

for i in range(num_cols):
    for j in range(i+1, num_cols):
        col_name = f"{col_names[i]}/{col_names[j]}"
        train_type_4[col_name] = train_type_4.iloc[:, i] / train_type_4.iloc[:, j]
        train_type_4[col_name] = train_type_4[col_name].abs()


num_cols = len(col_names)

for i in range(num_cols):
    for j in range(i+1, num_cols):
        col_name = f"{col_names[i]}/{col_names[j]}"
        train_type_5[col_name] = train_type_5.iloc[:, i] / train_type_5.iloc[:, j]
        train_type_5[col_name] = train_type_5[col_name].abs()

num_cols = len(col_names)

for i in range(num_cols):
    for j in range(i+1, num_cols):
        col_name = f"{col_names[i]}/{col_names[j]}"
        train_type_6[col_name] = train_type_6.iloc[:, i] / train_type_6.iloc[:, j]
        train_type_6[col_name] = train_type_6[col_name].abs()


num_cols = len(col_names)

for i in range(num_cols):
    for j in range(i+1, num_cols):
        col_name = f"{col_names[i]}/{col_names[j]}"
        train_type_7[col_name] = train_type_7.iloc[:, i] / train_type_7.iloc[:, j]  
        train_type_7[col_name] = train_type_7[col_name].abs()

# %%
num_cols = len(col_names)

for i in range(num_cols):
    for j in range(i+1, num_cols):
        col_name = f"{col_names[i]}/{col_names[j]}"
        test_type_0[col_name] = test_type_0.iloc[:, i] / test_type_0.iloc[:, j]

num_cols = len(col_names)

for i in range(num_cols):
    for j in range(i+1, num_cols):
        col_name = f"{col_names[i]}/{col_names[j]}"
        test_type_1[col_name] = test_type_1.iloc[:, i] / test_type_1.iloc[:, j]


num_cols = len(col_names)

for i in range(num_cols):
    for j in range(i+1, num_cols):
        col_name = f"{col_names[i]}/{col_names[j]}"
        test_type_2[col_name] = test_type_2.iloc[:, i] / test_type_2.iloc[:, j]

num_cols = len(col_names)

for i in range(num_cols):
    for j in range(i+1, num_cols):
        col_name = f"{col_names[i]}/{col_names[j]}"
        test_type_3[col_name] = test_type_3.iloc[:, i] / test_type_3.iloc[:, j] 

num_cols = len(col_names)

for i in range(num_cols):
    for j in range(i+1, num_cols):
        col_name = f"{col_names[i]}/{col_names[j]}"
        test_type_4[col_name] = test_type_4.iloc[:, i] / test_type_4.iloc[:, j]


num_cols = len(col_names)

for i in range(num_cols):
    for j in range(i+1, num_cols):
        col_name = f"{col_names[i]}/{col_names[j]}"
        test_type_5[col_name] = test_type_5.iloc[:, i] / test_type_5.iloc[:, j]


num_cols = len(col_names)

for i in range(num_cols):
    for j in range(i+1, num_cols):
        col_name = f"{col_names[i]}/{col_names[j]}"
        test_type_6[col_name] = test_type_6.iloc[:, i] / test_type_6.iloc[:, j]


num_cols = len(col_names)

for i in range(num_cols):
    for j in range(i+1, num_cols):
        col_name = f"{col_names[i]}/{col_names[j]}"
        test_type_7[col_name] = test_type_7.iloc[:, i] / test_type_7.iloc[:, j]

# %%
columns = train_type_0.columns

scaler.fit(train_type_0)
train_type_0 = scaler.transform(train_type_0)
test_type_0 = scaler.transform(test_type_0)
train_type_0 = pd.DataFrame(train_type_0)
test_type_0 = pd.DataFrame(test_type_0)
train_type_0.columns  = columns
test_type_0.columns  = columns

scaler.fit(train_type_1)
train_type_1 = scaler.transform(train_type_1)
test_type_1 = scaler.transform(test_type_1)
train_type_1 = pd.DataFrame(train_type_1)
test_type_1 = pd.DataFrame(test_type_1)
train_type_1.columns  = columns
test_type_1.columns  = columns


scaler.fit(train_type_2)
train_type_2 = scaler.transform(train_type_2)
test_type_2 = scaler.transform(test_type_2)
train_type_2 = pd.DataFrame(train_type_2)
test_type_2 = pd.DataFrame(test_type_2)
train_type_2.columns  =  columns
test_type_2.columns  = columns


scaler.fit(train_type_3)
train_type_3 = scaler.transform(train_type_3)
test_type_3 = scaler.transform(test_type_3)
train_type_3 = pd.DataFrame(train_type_3)
test_type_3 = pd.DataFrame(test_type_3)
train_type_3.columns  = columns
test_type_3.columns  = columns

scaler.fit(train_type_4)
train_type_4 = scaler.transform(train_type_4)
test_type_4 = scaler.transform(test_type_4)
train_type_4 = pd.DataFrame(train_type_4)
test_type_4 = pd.DataFrame(test_type_4)
train_type_4.columns  = columns
test_type_4.columns  =  columns

scaler.fit(train_type_5)
train_type_5 = scaler.transform(train_type_5)
test_type_5 = scaler.transform(test_type_5)
train_type_5 = pd.DataFrame(train_type_5)
test_type_5 = pd.DataFrame(test_type_5)
train_type_5.columns  = columns
test_type_5.columns  = columns

scaler.fit(train_type_6)
train_type_6 = scaler.transform(train_type_6)
test_type_6 = scaler.transform(test_type_6)
train_type_6 = pd.DataFrame(train_type_6)
test_type_6 = pd.DataFrame(test_type_6)
train_type_6.columns  =  columns
test_type_6.columns  =  columns

scaler.fit(train_type_7)
train_type_7 = scaler.transform(train_type_7)
test_type_7 = scaler.transform(test_type_7)
train_type_7 = pd.DataFrame(train_type_7)
test_type_7 = pd.DataFrame(test_type_7)
train_type_7.columns  =  columns
test_type_7.columns  = columns

# %%
train_type_7
# Out:
#      air_inflow  motor_rpm  motor_temp  motor_current  air_end_temp  \
# 0      0.378378   0.379369    0.379363       0.379491      0.379475
# 1      0.662162   0.659847    0.659762       0.659923      0.659734
# 2      0.445946   0.443308    0.443422       0.443321      0.443232
# 3      0.000000   0.000000    0.000000       0.000000      0.000000
# 4      0.351351   0.349105    0.349060       0.349145      0.349131
# ..          ...        ...         ...            ...           ...
# 181    0.518018   0.517903    0.517837       0.517963      0.517900
# 182    0.409910   0.406650    0.406598       0.406697      0.406751
# 183    0.027027   0.024723    0.024933       0.024765      0.024889
# 184    0.036036   0.033674    0.033755       0.033484      0.033754
# 185    0.716216   0.715260    0.715382       0.715382      0.715309
#
#      motor_vibe  out_pressure  air_inflow/motor_rpm  air_inflow/motor_temp  \
# ...

# %% [markdown]
# # 생성한 컬럼끼리 한번 빼봄(의미 없음)

# %%
#생성한 컬럼 끼리 한번 뺴봤습니다. 의미는 없는듯 
col_names = train_type_7.columns
num_cols = len(col_names)

for i in range(7,22):
    for j in range(i+1, 21):
        col_name = f"{col_names[i]}-{col_names[j]}"
        train_type_0[col_name] = train_type_0.iloc[:, i] - train_type_0.iloc[:, j]
        train_type_0[col_name] = train_type_0[col_name].abs()


num_cols = len(col_names)

for i in range(7,22):
    for j in range(i+1, 21):
        col_name = f"{col_names[i]}-{col_names[j]}"
        train_type_1[col_name] = train_type_1.iloc[:, i] - train_type_1.iloc[:, j]
        train_type_1[col_name] = train_type_1[col_name].abs()


num_cols = len(col_names)

for i in range(7,22):
    for j in range(i+1, 21):
        col_name = f"{col_names[i]}-{col_names[j]}"
        train_type_2[col_name] = train_type_2.iloc[:, i] - train_type_2.iloc[:, j]
        train_type_2[col_name] = train_type_2[col_name].abs()


num_cols = len(col_names)

for i in range(7,22):
    for j in range(i+1, 21):
        col_name = f"{col_names[i]}-{col_names[j]}"
        train_type_3[col_name] = train_type_3.iloc[:, i] - train_type_3.iloc[:, j] 
        train_type_3[col_name] = train_type_3[col_name].abs()


num_cols = len(col_names)

for i in range(7,22):
    for j in range(i+1, 21):
        col_name = f"{col_names[i]}-{col_names[j]}"
        train_type_4[col_name] = train_type_4.iloc[:, i] - train_type_4.iloc[:, j]
        train_type_4[col_name] = train_type_4[col_name].abs()


num_cols = len(col_names)

for i in range(7,22):
    for j in range(i+1, 21):
        col_name = f"{col_names[i]}-{col_names[j]}"
        train_type_5[col_name] = train_type_5.iloc[:, i] - train_type_5.iloc[:, j]
        train_type_5[col_name] = train_type_5[col_name].abs()

num_cols = len(col_names)

for i in range(7,22):
    for j in range(i+1, 21):
        col_name = f"{col_names[i]}-{col_names[j]}"
        train_type_6[col_name] = train_type_6.iloc[:, i] - train_type_6.iloc[:, j]
        train_type_6[col_name] = train_type_6[col_name].abs()


num_cols = len(col_names)

for i in range(7,22):
    for j in range(i+1, 21):
        col_name = f"{col_names[i]}-{col_names[j]}"
        train_type_7[col_name] = train_type_7.iloc[:, i] - train_type_7.iloc[:, j]  
        train_type_7[col_name] = train_type_7[col_name].abs()

# %%
#스케일링 후 시각화 해보면 각 컬럼의 value들이 대부분 같은 값을 가짐, 이 value들이 차이가 날때가 이상치?-> 차이를 구함
col_names = test_type_0.columns
num_cols = len(col_names)

for i in range(7,22):
    for j in range(i+1, 21):
        col_name = f"{col_names[i]}-{col_names[j]}"
        test_type_0[col_name] = test_type_0.iloc[:, i] - test_type_0.iloc[:, j]
        test_type_0[col_name] = test_type_0[col_name].abs()


num_cols = len(col_names)

for i in range(7,22):
    for j in range(i+1, 21):
        col_name = f"{col_names[i]}-{col_names[j]}"
        test_type_1[col_name] = test_type_1.iloc[:, i] - test_type_1.iloc[:, j]
        test_type_1[col_name] = test_type_1[col_name].abs()


num_cols = len(col_names)

for i in range(7,22):
    for j in range(i+1, 21):
        col_name = f"{col_names[i]}-{col_names[j]}"
        test_type_2[col_name] = test_type_2.iloc[:, i] - test_type_2.iloc[:, j]
        test_type_2[col_name] = test_type_2[col_name].abs()


num_cols = len(col_names)

for i in range(7,22):
    for j in range(i+1, 21):
        col_name = f"{col_names[i]}-{col_names[j]}"
        test_type_3[col_name] = test_type_3.iloc[:, i] - test_type_3.iloc[:, j] 
        test_type_3[col_name] = test_type_3[col_name].abs()


num_cols = len(col_names)

for i in range(7,22):
    for j in range(i+1, 21):
        col_name = f"{col_names[i]}-{col_names[j]}"
        test_type_4[col_name] = test_type_4.iloc[:, i] - test_type_4.iloc[:, j]
        test_type_4[col_name] = test_type_4[col_name].abs()


num_cols = len(col_names)

for i in range(7,22):
    for j in range(i+1, 21):
        col_name = f"{col_names[i]}-{col_names[j]}"
        test_type_5[col_name] = test_type_5.iloc[:, i] - test_type_5.iloc[:, j]
        test_type_5[col_name] = test_type_5[col_name].abs()

num_cols = len(col_names)

for i in range(7,22):
    for j in range(i+1, 21):
        col_name = f"{col_names[i]}-{col_names[j]}"
        test_type_6[col_name] = test_type_6.iloc[:, i] - test_type_6.iloc[:, j]
        test_type_6[col_name] = test_type_6[col_name].abs()


num_cols = len(col_names)

for i in range(7,22):
    for j in range(i+1, 21):
        col_name = f"{col_names[i]}-{col_names[j]}"
        test_type_7[col_name] = test_type_7.iloc[:, i] - test_type_7.iloc[:, j]  
        test_type_7[col_name] = test_type_7[col_name].abs()

# %%
from tensorflow.keras.models import Model, Sequential, load_model
from tensorflow.keras.layers import *

# %% [markdown]
# # 모델 학습(auto encoder) type별로 모델학습, 모든 컬럼 사용

# %%
callbacks = [tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.9, patience=1, verbose=0,
    mode='auto', min_delta=0.0001, cooldown=0, min_lr=0
),
tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', min_delta=0, patience=20, verbose=0,
    mode='auto', baseline=None, restore_best_weights=True
)]

# %%
test_type_0 = test_type_0.iloc[:,:]
test_type_1 = test_type_1.iloc[:,:]
test_type_2 = test_type_2.iloc[:,:]
test_type_3 = test_type_3.iloc[:,:]
test_type_4 = test_type_4.iloc[:,:]
test_type_5 = test_type_5.iloc[:,:]
test_type_6 = test_type_6.iloc[:,:]
test_type_7 = test_type_7.iloc[:,:]

train_type_0 = train_type_0.iloc[:,:]
train_type_1 = train_type_1.iloc[:,:]
train_type_2 = train_type_2.iloc[:,:]
train_type_3 = train_type_3.iloc[:,:]
train_type_4 = train_type_4.iloc[:,:]
train_type_5 = train_type_5.iloc[:,:]
train_type_6 = train_type_6.iloc[:,:]
train_type_7 = train_type_7.iloc[:,:]

# %%
columns = test_type_7.columns# 추가한 변수랑 원래 변수랑 스케일이 달라서 스케일링 한번 더해줌
scaler.fit(train_type_0)
train_type_0 = scaler.transform(train_type_0)
test_type_0 = scaler.transform(test_type_0)
train_type_0 = pd.DataFrame(train_type_0)
test_type_0 = pd.DataFrame(test_type_0)
train_type_0.columns  = columns
test_type_0.columns  = columns

scaler.fit(train_type_1)
train_type_1 = scaler.transform(train_type_1)
test_type_1 = scaler.transform(test_type_1)
train_type_1 = pd.DataFrame(train_type_1)
test_type_1 = pd.DataFrame(test_type_1)
train_type_1.columns  = columns
test_type_1.columns  = columns


scaler.fit(train_type_2)
train_type_2 = scaler.transform(train_type_2)
test_type_2 = scaler.transform(test_type_2)
train_type_2 = pd.DataFrame(train_type_2)
test_type_2 = pd.DataFrame(test_type_2)
train_type_2.columns  =  columns
test_type_2.columns  = columns


scaler.fit(train_type_3)
train_type_3 = scaler.transform(train_type_3)
test_type_3 = scaler.transform(test_type_3)
train_type_3 = pd.DataFrame(train_type_3)
test_type_3 = pd.DataFrame(test_type_3)
train_type_3.columns  = columns
test_type_3.columns  = columns

scaler.fit(train_type_4)
train_type_4 = scaler.transform(train_type_4)
test_type_4 = scaler.transform(test_type_4)
train_type_4 = pd.DataFrame(train_type_4)
test_type_4 = pd.DataFrame(test_type_4)
train_type_4.columns  = columns
test_type_4.columns  =  columns

scaler.fit(train_type_5)
train_type_5 = scaler.transform(train_type_5)
test_type_5 = scaler.transform(test_type_5)
train_type_5 = pd.DataFrame(train_type_5)
test_type_5 = pd.DataFrame(test_type_5)
train_type_5.columns  = columns
test_type_5.columns  = columns

scaler.fit(train_type_6)
train_type_6 = scaler.transform(train_type_6)
test_type_6 = scaler.transform(test_type_6)
train_type_6 = pd.DataFrame(train_type_6)
test_type_6 = pd.DataFrame(test_type_6)
train_type_6.columns  =  columns
test_type_6.columns  =  columns

scaler.fit(train_type_7)
train_type_7 = scaler.transform(train_type_7)
test_type_7 = scaler.transform(test_type_7)
train_type_7 = pd.DataFrame(train_type_7)
test_type_7 = pd.DataFrame(test_type_7)
train_type_7.columns  =  columns
test_type_7.columns  = columns

# %%
from keras import regularizers
TEST_SIZE = 0.05
RANDOM_SEED = 42
X_train, X_test = train_test_split(train_type_0, test_size=TEST_SIZE, random_state=RANDOM_SEED)

TEST_SIZE = 0.10
RANDOM_SEED = 42
X_train, X_val = train_test_split(X_train, test_size=TEST_SIZE, random_state=RANDOM_SEED)
def dnn(x):
    input_dim = x.shape[1]
    input = Input(shape=(input_dim, ))
    
    encode = Dense(64, activation='relu')(input)
    encode = Dense(32, activation='relu')(encode)                                    
    decode = Dense(32, activation='relu')(encode)
    decode = Dense(64, activation='relu')(decode)
    decode = Dense(input_dim, activation='relu')(decode)
    autoencoder = Model(input, decode)

    autoencoder.summary()
    
    return autoencoder
model = dnn(X_train)
model.compile(optimizer='adam', loss='mae')

epochs = 100
batch = 32
history = model.fit(X_train, X_train,
                      epochs=epochs, batch_size=batch,
                      validation_data=(X_val, X_val), callbacks=callbacks)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 113)]             0
#
#  dense (Dense)               (None, 64)                7296
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 32)                1056
#
#  dense_3 (Dense)             (None, 64)                2112
#
#  dense_4 (Dense)             (None, 113)               7345
#
# ...
# Total params: 19,889
# Trainable params: 19,889
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 12/12 [==============================] - 5s 61ms/step - loss: 0.3461 - val_loss: 0.3093 - lr: 0.0010
# Epoch 2/100
# 12/12 [==============================] - 0s 23ms/step - loss: 0.2873 - val_loss: 0.2744 - lr: 0.0010
# Epoch 3/100
# ...

# %%
x_train_pred = model.predict(X_train)
train_mae_loss = np.mean(np.abs(x_train_pred - np.array(X_train).reshape(x_train_pred.shape)),axis = 1)
plt.hist(train_mae_loss, bins=30)
plt.xlabel("Train MAE loss")
plt.ylabel("No of samples")
plt.show()
# Out:
# 12/12 [==============================] - 0s 2ms/step

# %%
x_train_pred = model.predict(X_train)
train_mae_loss = np.mean(np.abs(x_train_pred - np.array(X_train).reshape(x_train_pred.shape)), axis=1)
plt.hist(train_mae_loss, bins=10)
plt.xlabel("Train MAE loss")
plt.ylabel("No of samples")
plt.show()

# Get reconstruction loss threshold.
threshold = 3* np.max(train_mae_loss)
print("Reconstruction error threshold: ", threshold)


x_test_pred = model.predict(X_test)
test_mae_loss = np.mean(np.abs(x_test_pred - np.array(X_test).reshape(x_test_pred.shape)), axis=1)

plt.hist(test_mae_loss, bins=10)
plt.xlabel("test MAE loss")
plt.ylabel("No of samples")
plt.show()
pred = model.predict(test_type_0)
mae = np.mean(np.abs(np.array(test_type_0).reshape(pred.shape) - pred), axis=1)
x_test_pred = pred
test_mae_loss = np.mean(np.abs(x_test_pred - np.array(test_type_0).reshape(pred.shape)), axis=1)


plt.hist(test_mae_loss, bins=10)
plt.xlabel("test MAE loss")
plt.ylabel("No of samples")
plt.show()

Q1 =  np.quantile(test_mae_loss, 0.25)
Q3 =  np.quantile(test_mae_loss, 0.75)
IQR = np.subtract(*np.quantile(test_mae_loss, [0.75, 0.25]))
threshold = 3* np.max(train_mae_loss)
# Out:
# 12/12 [==============================] - 0s 2ms/step
# Reconstruction error threshold:  0.37554108919178886
# ...
# 41/41 [==============================] - 0s 2ms/step

# %%
idx = np.where(test_mae_loss >threshold)
test_type_0 = pd.DataFrame(test_type_0).reset_index(drop = True)
test_type_0["target"] = 0
test_type_0.loc[idx[0], "target"] = 1

# %%
test_type_0[test_type_0["target"] == 1]
# Out:
#      air_inflow  motor_rpm  motor_temp  motor_current  air_end_temp  \
# 585    0.107623   0.188455    0.188312       0.220486      0.222411
# 586    0.412556   0.538625    0.226509       0.586458      0.572496
# 587    0.094170   0.173599    0.264706       0.204861      0.207470
# 588    0.771300   0.945246    0.302903       1.011458      0.979287
# 589    0.215247   0.311545    0.341100       0.348958      0.345331
# ..          ...        ...         ...            ...           ...
# 723   -0.098655   0.026740    0.033995       0.100347      0.162649
# 724    0.219731   0.446095    0.446142       0.576736      0.582003
# 725    0.345291   0.607385    0.607334       0.760069      0.743294
# 726    0.417040   0.704584    0.704736       0.870486      0.840407
# 727    0.161435   0.367148    0.367074       0.487153      0.502886
#
#      motor_vibe  out_pressure  air_inflow/motor_rpm  air_inflow/motor_temp  \
# ...

# %%
plt.plot(test_type_0.iloc[584:729,-1])

# %%
plt.plot(test_type_0.iloc[584:729,:21])

# %%
from keras import regularizers
TEST_SIZE = 0.05
RANDOM_SEED = 42
X_train, X_test = train_test_split(train_type_1, test_size=TEST_SIZE, random_state=RANDOM_SEED)

TEST_SIZE = 0.10
RANDOM_SEED = 42
X_train, X_val = train_test_split(X_train, test_size=TEST_SIZE, random_state=RANDOM_SEED)
def dnn(x):
    input_dim = x.shape[1]
    input = Input(shape=(input_dim, ))
    
    encode = Dense(64, activation='relu')(input)
    encode = Dense(32, activation='relu')(encode)                                    
    decode = Dense(32, activation='relu')(encode)
    decode = Dense(64, activation='relu')(decode)
    decode = Dense(input_dim, activation='relu')(decode)
    autoencoder = Model(input, decode)

    autoencoder.summary()
    
    return autoencoder
model = dnn(X_train)
model.compile(optimizer='adam', loss='mae')

epochs = 100
batch = 32
history = model.fit(X_train, X_train,
                      epochs=epochs, batch_size=batch,
                      validation_data=(X_val, X_val), callbacks=callbacks)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_2 (InputLayer)        [(None, 113)]             0
#
#  dense_5 (Dense)             (None, 64)                7296
#
#  dense_6 (Dense)             (None, 32)                2080
#
#  dense_7 (Dense)             (None, 32)                1056
#
#  dense_8 (Dense)             (None, 64)                2112
#
#  dense_9 (Dense)             (None, 113)               7345
#
# ...
# Total params: 19,889
# Trainable params: 19,889
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 10/10 [==============================] - 2s 25ms/step - loss: 0.3720 - val_loss: 0.3226 - lr: 0.0010
# Epoch 2/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3192 - val_loss: 0.2883 - lr: 0.0010
# Epoch 3/100
# ...

# %%
x_train_pred = model.predict(X_train)
train_mae_loss = np.mean(np.abs(x_train_pred - X_train), axis=1)
plt.hist(train_mae_loss, bins=30)
plt.xlabel("Train MAE loss")
plt.ylabel("No of samples")
plt.show()

# Get reconstruction loss threshold.
threshold = 3* np.max(train_mae_loss)
print("Reconstruction error threshold: ", threshold)


x_test_pred = model.predict(X_test)
test_mae_loss = np.mean(np.abs(x_test_pred - X_test), axis=1)

plt.hist(test_mae_loss, bins=50)
plt.xlabel("test MAE loss")
plt.ylabel("No of samples")
plt.show()
pred = model.predict(test_type_1)
mae = np.mean(np.abs(test_type_1 - pred), axis=1)
x_test_pred = pred
test_mae_loss = np.mean(np.abs(x_test_pred - test_type_1), axis=1)


plt.hist(test_mae_loss, bins=50)
plt.xlabel("test MAE loss")
plt.ylabel("No of samples")
plt.show()

Q1 =  np.quantile(train_mae_loss, 0.25)
Q3 =  np.quantile(train_mae_loss, 0.75)
IQR = np.subtract(*np.quantile(train_mae_loss, [0.75, 0.25]))
threshold = 3* np.max(train_mae_loss)
idx = np.where(test_mae_loss >threshold)
test_type_1 = pd.DataFrame(test_type_1).reset_index(drop = True)
test_type_1["target"] = 0
test_type_1.loc[idx[0], "target"] = 1
# Out:
# 10/10 [==============================] - 0s 2ms/step
# Reconstruction error threshold:  0.64363926203331
# ...
# 35/35 [==============================] - 0s 2ms/step

# %%
test_type_1[test_type_1["target"] == 1]
# Out:
# Empty DataFrame
# ...

# %%
from keras import regularizers
TEST_SIZE = 0.05
RANDOM_SEED = 42
X_train, X_test = train_test_split(train_type_2, test_size=TEST_SIZE, random_state=RANDOM_SEED)

TEST_SIZE = 0.10
RANDOM_SEED = 42
X_train, X_val = train_test_split(X_train, test_size=TEST_SIZE, random_state=RANDOM_SEED)
def dnn(x):
    input_dim = x.shape[1]
    input = Input(shape=(input_dim, ))
    
    encode = Dense(64, activation='relu')(input)
    encode = Dense(32, activation='relu')(encode)                                    
    decode = Dense(32, activation='relu')(encode)
    decode = Dense(64, activation='relu')(decode)
    decode = Dense(input_dim, activation='relu')(decode)
    autoencoder = Model(input, decode)

    autoencoder.summary()
    
    return autoencoder
model = dnn(X_train)
model.compile(optimizer='adam', loss='mae')

epochs = 100
batch = 32
history = model.fit(X_train, X_train,
                      epochs=epochs, batch_size=batch,
                      validation_data=(X_val, X_val), callbacks=callbacks)
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_3 (InputLayer)        [(None, 113)]             0
#
#  dense_10 (Dense)            (None, 64)                7296
#
#  dense_11 (Dense)            (None, 32)                2080
#
#  dense_12 (Dense)            (None, 32)                1056
#
#  dense_13 (Dense)            (None, 64)                2112
#
#  dense_14 (Dense)            (None, 113)               7345
#
# ...
# Total params: 19,889
# Trainable params: 19,889
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 10/10 [==============================] - 2s 23ms/step - loss: 0.3719 - val_loss: 0.3530 - lr: 0.0010
# Epoch 2/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.3151 - val_loss: 0.3080 - lr: 0.0010
# Epoch 3/100
# ...

# %%
x_train_pred = model.predict(X_train)
train_mae_loss = np.mean(np.abs(x_train_pred - X_train), axis=1)
plt.hist(train_mae_loss, bins=30)
plt.xlabel("Train MAE loss")
plt.ylabel("No of samples")
plt.show()

# Get reconstruction loss threshold.
threshold = 3* np.max(train_mae_loss)
print("Reconstruction error threshold: ", threshold)


x_test_pred = model.predict(X_test)
test_mae_loss = np.mean(np.abs(x_test_pred - X_test), axis=1)

plt.hist(test_mae_loss, bins=30)
plt.xlabel("test MAE loss")
plt.ylabel("No of samples")
plt.show()
pred = model.predict(test_type_2)
mae = np.mean(np.abs(test_type_2 - pred), axis=1)
x_test_pred = pred
test_mae_loss = np.mean(np.abs(x_test_pred - test_type_2), axis=1)


plt.hist(test_mae_loss, bins=30)
plt.xlabel("test MAE loss")
plt.ylabel("No of samples")
plt.show()

Q1 =  np.quantile(train_mae_loss, 0.25)
Q3 =  np.quantile(train_mae_loss, 0.75)
IQR = np.subtract(*np.quantile(train_mae_loss, [0.75, 0.25]))
threshold = 3* np.max(train_mae_loss)
idx = np.where(test_mae_loss >threshold)
test_type_2 = pd.DataFrame(test_type_2).reset_index(drop = True)
test_type_2["target"] = 0
test_type_2.loc[idx[0], "target"] = 1
# Out:
# 10/10 [==============================] - 0s 3ms/step
# Reconstruction error threshold:  0.39880232128679804
# ...
# 35/35 [==============================] - 0s 3ms/step

# %%
test_type_2[test_type_2["target"] == 1]
# Out:
#      air_inflow  motor_rpm  motor_temp  motor_current  air_end_temp  \
# 239    0.060606   0.347734    0.111704       0.112381      0.111826
# 240    0.272727   0.944091    0.354937       0.943810      0.944087
# 241    0.227273   0.674291    0.674037       0.674286      0.674348
# 242    0.348485   0.695044    0.695006       0.695238      0.695019
# 243    0.575758   0.694621    0.694624       0.694286      0.694680
# 244    0.500000   0.089792    0.089592       0.089524      0.089800
# 245    0.484848   0.138924    0.138772       0.139048      0.138936
# 246    0.257576   0.331639    0.331681       0.331429      0.331413
# 247    0.121212   0.872935    0.111704       0.112381      0.111826
# 248    0.136364   0.132571    0.393061       0.462857      0.132497
# 249    0.181818   0.176620    0.348456       0.413333      0.176550
# 250    0.939394   0.941974    0.485322       0.566667      0.942054
# 251    0.409091   0.400254    0.728174       0.840000      0.400203
# ...

# %%
plt.plot(test_type_2.iloc[238:267,-1])

# %%
plt.plot(test_type_2.iloc[238:267,:21])

# %%
x_train_pred = model.predict(X_train)
train_mae_loss = np.mean(np.abs(x_train_pred - X_train), axis=1)
plt.hist(train_mae_loss, bins=30)
plt.xlabel("Train MAE loss")
plt.ylabel("No of samples")
plt.show()

# Get reconstruction loss threshold.
threshold = 3* np.max(train_mae_loss)
print("Reconstruction error threshold: ", threshold)


x_test_pred = model.predict(X_test)
test_mae_loss = np.mean(np.abs(x_test_pred - X_test), axis=1)

plt.hist(test_mae_loss, bins=50)
plt.xlabel("test MAE loss")
plt.ylabel("No of samples")
plt.show()
pred = model.predict(test_type_3)
mae = np.mean(np.abs(test_type_3 - pred), axis=1)
x_test_pred = pred
test_mae_loss = np.mean(np.abs(x_test_pred - test_type_3), axis=1)


plt.hist(test_mae_loss, bins=50)
plt.xlabel("test MAE loss")
plt.ylabel("No of samples")
plt.show()

Q1 =  np.quantile(train_mae_loss, 0.25)
Q3 =  np.quantile(train_mae_loss, 0.75)
IQR = np.subtract(*np.quantile(train_mae_loss, [0.75, 0.25]))
threshold = 3* np.max(train_mae_loss)

idx = np.where(test_mae_loss >threshold)
test_type_3 = pd.DataFrame(test_type_3).reset_index(drop = True)
test_type_3["target"] = 0
test_type_3.loc[idx[0], "target"] = 1
# Out:
# 10/10 [==============================] - 0s 3ms/step
# Reconstruction error threshold:  0.39880232128679804
# ...
# 29/29 [==============================] - 0s 2ms/step

# %%
from keras import regularizers
TEST_SIZE = 0.05
RANDOM_SEED = 42
X_train, X_test = train_test_split(train_type_3, test_size=TEST_SIZE, random_state=RANDOM_SEED)

TEST_SIZE = 0.10
RANDOM_SEED = 42
X_train, X_val = train_test_split(X_train, test_size=TEST_SIZE, random_state=RANDOM_SEED)
def dnn(x):
    input_dim = x.shape[1]
    input = Input(shape=(input_dim, ))
    
    encode = Dense(64, activation='relu')(input)
    encode = Dense(32, activation='relu')(encode)                                    
    decode = Dense(32, activation='relu')(encode)
    decode = Dense(64, activation='relu')(decode)
    decode = Dense(input_dim, activation='relu')(decode)
    autoencoder = Model(input, decode)

    autoencoder.summary()
    
    return autoencoder
model = dnn(X_train)
model.compile(optimizer='adam', loss='mae')

epochs = 100
batch = 32
history = model.fit(X_train, X_train,
                      epochs=epochs, batch_size=batch,
                      validation_data=(X_val, X_val), callbacks=callbacks)
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_4 (InputLayer)        [(None, 113)]             0
#
#  dense_15 (Dense)            (None, 64)                7296
#
#  dense_16 (Dense)            (None, 32)                2080
#
#  dense_17 (Dense)            (None, 32)                1056
#
#  dense_18 (Dense)            (None, 64)                2112
#
#  dense_19 (Dense)            (None, 113)               7345
#
# ...
# Total params: 19,889
# Trainable params: 19,889
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 9/9 [==============================] - 2s 29ms/step - loss: 0.4042 - val_loss: 0.3382 - lr: 0.0010
# Epoch 2/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.3268 - val_loss: 0.2961 - lr: 0.0010
# Epoch 3/100
# ...

# %%
test_type_3[test_type_3["target"] == 1]
# Out:
#      air_inflow  motor_rpm  motor_temp  motor_current  air_end_temp  \
# 439    0.245742   0.284743    0.437643       0.354167      0.352941
# 440    0.128954   0.161496    0.314461       0.229167      0.229514
# 441    0.851582   0.918402    1.071538       1.041667      0.986399
# 442    0.413625   0.460688    0.613619       0.541667      0.528732
# 443    0.133820   0.166171    0.319051       0.229167      0.234274
# 444    0.257908   0.296218    0.449120       0.375000      0.364162
# 445    0.279805   0.318317    0.471308       0.395833      0.386263
# 446    0.656934   0.714832    0.868018       0.812500      0.783067
# 447    0.002433   0.029324    0.182096       0.083333      0.097246
# 448    0.046229   0.075648    0.228768       0.125000      0.143829
# 449    0.827251   0.892478    1.045524       1.020833      0.960558
# 450    0.540146   0.592010    0.745218       0.687500      0.659980
# 451    0.656934   0.715682    0.868783       0.812500      0.783747
# ...

# %%
plt.plot(test_type_3.iloc[438:466,-1])

# %%
plt.plot(test_type_3.iloc[438:466,:21])

# %%
from keras import regularizers
TEST_SIZE = 0.05
RANDOM_SEED = 42
X_train, X_test = train_test_split(train_type_4, test_size=TEST_SIZE, random_state=RANDOM_SEED)

TEST_SIZE = 0.10
RANDOM_SEED = 42
X_train, X_val = train_test_split(X_train, test_size=TEST_SIZE, random_state=RANDOM_SEED)
def dnn(x):
    input_dim = x.shape[1]
    input = Input(shape=(input_dim, ))
    
    encode = Dense(64, activation='relu')(input)
    encode = Dense(32, activation='relu')(encode)                                    
    decode = Dense(32, activation='relu')(encode)
    decode = Dense(64, activation='relu')(decode)
    decode = Dense(input_dim, activation='relu')(decode)
    autoencoder = Model(input, decode)

    autoencoder.summary()
    
    return autoencoder
model = dnn(X_train)
model.compile(optimizer='adam', loss='mae')

epochs = 100
batch = 32
history = model.fit(X_train, X_train,
                      epochs=epochs, batch_size=batch,
                      validation_data=(X_val, X_val), callbacks=callbacks)
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_5 (InputLayer)        [(None, 113)]             0
#
#  dense_20 (Dense)            (None, 64)                7296
#
#  dense_21 (Dense)            (None, 32)                2080
#
#  dense_22 (Dense)            (None, 32)                1056
#
#  dense_23 (Dense)            (None, 64)                2112
#
#  dense_24 (Dense)            (None, 113)               7345
#
# ...
# Total params: 19,889
# Trainable params: 19,889
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 9/9 [==============================] - 2s 26ms/step - loss: 0.3561 - val_loss: 0.3134 - lr: 0.0010
# Epoch 2/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3015 - val_loss: 0.2738 - lr: 0.0010
# Epoch 3/100
# ...

# %%
x_train_pred = model.predict(X_train)
train_mae_loss = np.mean(np.abs(x_train_pred - X_train), axis=1)
plt.hist(train_mae_loss, bins=30)
plt.xlabel("Train MAE loss")
plt.ylabel("No of samples")
plt.show()

# Get reconstruction loss threshold.
threshold = 3* np.max(train_mae_loss)
print("Reconstruction error threshold: ", threshold)


x_test_pred = model.predict(X_test)
test_mae_loss = np.mean(np.abs(x_test_pred - X_test), axis=1)

plt.hist(test_mae_loss, bins=30)
plt.xlabel("test MAE loss")
plt.ylabel("No of samples")
plt.show()
pred = model.predict(test_type_4)
mae = np.mean(np.abs(test_type_4 - pred), axis=1)
x_test_pred = pred
test_mae_loss = np.mean(np.abs(x_test_pred - test_type_4), axis=1)


plt.hist(test_mae_loss, bins=30)
plt.xlabel("test MAE loss")
plt.ylabel("No of samples")
plt.show()

Q1 =  np.quantile(train_mae_loss, 0.25)
Q3 =  np.quantile(train_mae_loss, 0.75)
IQR = np.subtract(*np.quantile(train_mae_loss, [0.75, 0.25]))
threshold = 3* np.max(train_mae_loss)
idx = np.where(test_mae_loss >threshold)
test_type_4 = pd.DataFrame(test_type_4).reset_index(drop = True)
test_type_4["target"] = 0
test_type_4.loc[idx[0], "target"] = 1
# Out:
# 9/9 [==============================] - 0s 2ms/step
# Reconstruction error threshold:  0.42612973157251377
# ...
# 29/29 [==============================] - 0s 2ms/step

# %%
test_type_4[test_type_4["target"] == 1]
# Out:
#      air_inflow  motor_rpm  motor_temp  motor_current  air_end_temp  \
# 847    0.283784   0.310345    0.310345       0.310345      0.378406
# 848    0.792793   0.874415    0.874330       0.874260      0.976499
# 849    0.171171   0.261814    0.261686       0.261930      0.398161
# 850    0.135135   0.276288    0.276245       0.276210      0.446526
# 851    0.279279   0.485313    0.485441       0.485197      0.689714
# 852    0.144144   0.421030    0.421073       0.421108      0.931880
#
#      motor_vibe  out_pressure  air_inflow/motor_rpm  air_inflow/motor_temp  \
# 847    0.307692           0.0             -3.674477               0.355101
# 848    0.876923           0.0             -7.350221               0.798106
# 849    0.261538           0.0            -15.163774               0.185458
# 850    0.276923           0.0            -23.562629               0.114614
# 851    0.484615           0.0            -27.360708               0.252093
# ...

# %%
plt.plot(test_type_4.iloc[846:854,-1])

# %%
plt.plot(test_type_4.iloc[846:854,:21])

# %%
from keras import regularizers
TEST_SIZE = 0.05
RANDOM_SEED = 42
X_train, X_test = train_test_split(train_type_5, test_size=TEST_SIZE, random_state=RANDOM_SEED)

TEST_SIZE = 0.10
RANDOM_SEED = 42
X_train, X_val = train_test_split(X_train, test_size=TEST_SIZE, random_state=RANDOM_SEED)
def dnn(x):
    input_dim = x.shape[1]
    input = Input(shape=(input_dim, ))
    
    encode = Dense(64, activation='relu')(input)
    encode = Dense(32, activation='relu')(encode)                                    
    decode = Dense(32, activation='relu')(encode)
    decode = Dense(64, activation='relu')(decode)
    decode = Dense(input_dim, activation='relu')(decode)
    autoencoder = Model(input, decode)

    autoencoder.summary()
    
    return autoencoder
model = dnn(X_train)
model.compile(optimizer='adam', loss='mae')

epochs = 100
batch = 32
history = model.fit(X_train, X_train,
                      epochs=epochs, batch_size=batch,
                      validation_data=(X_val, X_val), callbacks=callbacks)
# Out:
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_6 (InputLayer)        [(None, 113)]             0
#
#  dense_25 (Dense)            (None, 64)                7296
#
#  dense_26 (Dense)            (None, 32)                2080
#
#  dense_27 (Dense)            (None, 32)                1056
#
#  dense_28 (Dense)            (None, 64)                2112
#
#  dense_29 (Dense)            (None, 113)               7345
#
# ...
# Total params: 19,889
# Trainable params: 19,889
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 7/7 [==============================] - 3s 120ms/step - loss: 0.3627 - val_loss: 0.3318 - lr: 0.0010
# Epoch 2/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3166 - val_loss: 0.2932 - lr: 0.0010
# Epoch 3/100
# ...

# %%
x_train_pred = model.predict(X_train)
train_mae_loss = np.mean(np.abs(x_train_pred - X_train), axis=1)
plt.hist(train_mae_loss, bins=30)
plt.xlabel("Train MAE loss")
plt.ylabel("No of samples")
plt.show()

# Get reconstruction loss threshold.
threshold = 3* np.max(train_mae_loss)
print("Reconstruction error threshold: ", threshold)


x_test_pred = model.predict(X_test)
test_mae_loss = np.mean(np.abs(x_test_pred - X_test), axis=1)

plt.hist(test_mae_loss, bins=30)
plt.xlabel("test MAE loss")
plt.ylabel("No of samples")
plt.show()
pred = model.predict(test_type_5)
mae = np.mean(np.abs(test_type_5 - pred), axis=1)
x_test_pred = pred
test_mae_loss = np.mean(np.abs(x_test_pred - test_type_5), axis=1)


plt.hist(test_mae_loss, bins=30)
plt.xlabel("test MAE loss")
plt.ylabel("No of samples")
plt.show()

Q1 =  np.quantile(train_mae_loss, 0.25)
Q3 =  np.quantile(train_mae_loss, 0.75)
IQR = np.subtract(*np.quantile(train_mae_loss, [0.75, 0.25]))
threshold = 3* np.max(train_mae_loss)

idx = np.where(test_mae_loss >threshold)
test_type_5 = pd.DataFrame(test_type_5).reset_index(drop = True)
test_type_5["target"] = 0
test_type_5.loc[idx[0], "target"] = 1
# Out:
# 7/7 [==============================] - 0s 2ms/step
# Reconstruction error threshold:  0.3958079790348077
# ...
# 24/24 [==============================] - 0s 2ms/step

# %%
test_type_5[test_type_5["target"] == 1]
# Out:
#      air_inflow  motor_rpm  motor_temp  motor_current  air_end_temp  \
# 717    0.720721   0.884157    0.884247       0.947735      0.918228
# 718    0.630631   0.781942    0.781909       0.840767      0.816014
# 719    0.572072   0.715503    0.715600       0.771429      0.749574
# 720    0.333333   0.446763    0.446915       0.490592      0.480750
# 721    0.027027   0.099233    0.099272       0.127178      0.133220
# 722    0.004505   0.075383    0.075508       0.102091      0.109370
# 723    0.468468   0.600937    0.600997       0.651568      0.635094
# 724    0.585586   0.731261    0.731315       0.787805      0.765247
# 725    0.545045   0.686116    0.686087       0.740767      0.720273
# 726    0.684685   0.844974    0.845151       0.906620      0.879046
# 727    0.603604   0.753407    0.753545       0.811150      0.787394
# 728    0.765766   0.938671    0.938674       1.004878      0.972743
# 729    0.148649   0.236797    0.236872       0.271080      0.270869
# ...

# %%
plt.plot(test_type_5.iloc[716:747,-1])

# %%
plt.plot(test_type_5.iloc[716:747,:21])

# %%
from keras import regularizers
TEST_SIZE = 0.05
RANDOM_SEED = 42
X_train, X_test = train_test_split(train_type_6, test_size=TEST_SIZE, random_state=RANDOM_SEED)

TEST_SIZE = 0.10
RANDOM_SEED = 42
X_train, X_val = train_test_split(X_train, test_size=TEST_SIZE, random_state=RANDOM_SEED)
def dnn(x):
    input_dim = x.shape[1]
    input = Input(shape=(input_dim, ))
    
    encode = Dense(64, activation='relu')(input)
    encode = Dense(32, activation='relu')(encode)                                    
    decode = Dense(32, activation='relu')(encode)
    decode = Dense(64, activation='relu')(decode)
    decode = Dense(input_dim, activation='relu')(decode)
    autoencoder = Model(input, decode)

    autoencoder.summary()
    
    return autoencoder
model = dnn(X_train)
model.compile(optimizer='adam', loss='mae')

epochs = 100
batch = 32
history = model.fit(X_train, X_train,
                      epochs=epochs, batch_size=batch,
                      validation_data=(X_val, X_val), callbacks=callbacks)
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_7 (InputLayer)        [(None, 113)]             0
#
#  dense_30 (Dense)            (None, 64)                7296
#
#  dense_31 (Dense)            (None, 32)                2080
#
#  dense_32 (Dense)            (None, 32)                1056
#
#  dense_33 (Dense)            (None, 64)                2112
#
#  dense_34 (Dense)            (None, 113)               7345
#
# ...
# Total params: 19,889
# Trainable params: 19,889
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 7/7 [==============================] - 3s 48ms/step - loss: 0.3413 - val_loss: 0.3238 - lr: 0.0010
# Epoch 2/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.3034 - val_loss: 0.2997 - lr: 0.0010
# Epoch 3/100
# ...

# %%
x_train_pred = model.predict(X_train)
train_mae_loss = np.mean(np.abs(x_train_pred - X_train), axis=1)
plt.hist(train_mae_loss, bins=30)
plt.xlabel("Train MAE loss")
plt.ylabel("No of samples")
plt.show()

# Get reconstruction loss threshold.
threshold = 3* np.max(train_mae_loss)
print("Reconstruction error threshold: ", threshold)


x_test_pred = model.predict(X_test)
test_mae_loss = np.mean(np.abs(x_test_pred - X_test), axis=1)

plt.hist(test_mae_loss, bins=30)
plt.xlabel("test MAE loss")
plt.ylabel("No of samples")
plt.show()
pred = model.predict(test_type_6)
mae = np.mean(np.abs(test_type_6 - pred), axis=1)
x_test_pred = pred
test_mae_loss = np.mean(np.abs(x_test_pred - test_type_6), axis=1)


plt.hist(test_mae_loss, bins=30)
plt.xlabel("test MAE loss")
plt.ylabel("No of samples")
plt.show()

Q1 =  np.quantile(train_mae_loss, 0.25)
Q3 =  np.quantile(train_mae_loss, 0.75)
IQR = np.subtract(*np.quantile(train_mae_loss, [0.75, 0.25]))
threshold = 3* np.max(train_mae_loss)

idx = np.where(test_mae_loss >threshold)
test_type_6 = pd.DataFrame(test_type_6).reset_index(drop = True)
test_type_6["target"] = 0
test_type_6.loc[idx[0], "target"] = 1
# Out:
# 7/7 [==============================] - 0s 2ms/step
# Reconstruction error threshold:  0.4341197442580389
# ...
# 24/24 [==============================] - 0s 2ms/step

# %%
test_type_6[test_type_6["target"] == 1]
# Out:
#      air_inflow  motor_rpm  motor_temp  motor_current  air_end_temp  \
# 616    0.390909   0.513978    0.513744       0.561576      0.548176
# 617    0.463636   0.594839    0.594657       0.646024      0.629043
# 618    0.154545   0.246882    0.246612       0.282196      0.281142
# 619    0.622727   0.777204    0.777003       0.836735      0.811425
# 620    0.777273   0.954409    0.954317       1.021816      0.988644
# ..          ...        ...         ...            ...           ...
# 712   -0.127273   0.017204    0.024390       0.054539      0.189264
# 713    0.186364   0.442151    0.442122       0.508445      0.614246
# 714    0.304545   0.605591    0.605497       0.682970      0.777701
# 715    0.377273   0.704086    0.704220       0.788177      0.876118
# 716    0.127273   0.362151    0.361982       0.422942      0.534067
#
#      motor_vibe  out_pressure  air_inflow/motor_rpm  air_inflow/motor_temp  \
# ...

# %%
plt.plot(test_type_6.iloc[615:718,-1])

# %%
plt.plot(test_type_6.iloc[615:718,:21])

# %%
from keras import regularizers
TEST_SIZE = 0.05
RANDOM_SEED = 42
X_train, X_test = train_test_split(train_type_7, test_size=TEST_SIZE, random_state=RANDOM_SEED)

TEST_SIZE = 0.10
RANDOM_SEED = 42
X_train, X_val = train_test_split(X_train, test_size=TEST_SIZE, random_state=RANDOM_SEED)
def dnn(x):
    input_dim = x.shape[1]
    input = Input(shape=(input_dim, ))
    
    encode = Dense(64, activation='relu')(input)
    encode = Dense(32, activation='relu')(encode)                                    
    decode = Dense(32, activation='relu')(encode)
    decode = Dense(64, activation='relu')(decode)
    decode = Dense(input_dim, activation='relu')(decode)
    autoencoder = Model(input, decode)

    autoencoder.summary()
    
    return autoencoder
model = dnn(X_train)
model.compile(optimizer='adam', loss='mae')

epochs = 100
batch = 32
history = model.fit(X_train, X_train,
                      epochs=epochs, batch_size=batch,
                      validation_data=(X_val, X_val), callbacks=callbacks)
# Out:
# Model: "model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_8 (InputLayer)        [(None, 113)]             0
#
#  dense_35 (Dense)            (None, 64)                7296
#
#  dense_36 (Dense)            (None, 32)                2080
#
#  dense_37 (Dense)            (None, 32)                1056
#
#  dense_38 (Dense)            (None, 64)                2112
#
#  dense_39 (Dense)            (None, 113)               7345
#
# ...
# Total params: 19,889
# Trainable params: 19,889
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 5/5 [==============================] - 2s 67ms/step - loss: 0.3608 - val_loss: 0.3517 - lr: 0.0010
# Epoch 2/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.3345 - val_loss: 0.3309 - lr: 0.0010
# Epoch 3/100
# ...

# %%
x_train_pred = model.predict(X_train)
train_mae_loss = np.mean(np.abs(x_train_pred - X_train), axis=1)
plt.hist(train_mae_loss, bins=30)
plt.xlabel("Train MAE loss")
plt.ylabel("No of samples")
plt.show()

# Get reconstruction loss threshold.
threshold = 3* np.max(train_mae_loss)
print("Reconstruction error threshold: ", threshold)


x_test_pred = model.predict(X_test)
test_mae_loss = np.mean(np.abs(x_test_pred - X_test), axis=1)

plt.hist(test_mae_loss, bins=30)
plt.xlabel("test MAE loss")
plt.ylabel("No of samples")
plt.show()
pred = model.predict(test_type_7)
mae = np.mean(np.abs(test_type_7 - pred), axis=1)
x_test_pred = pred
test_mae_loss = np.mean(np.abs(x_test_pred - test_type_7), axis=1)


plt.hist(test_mae_loss, bins=30)
plt.xlabel("test MAE loss")
plt.ylabel("No of samples")
plt.show()

Q1 =  np.quantile(train_mae_loss, 0.25)
Q3 =  np.quantile(train_mae_loss, 0.75)
IQR = np.subtract(*np.quantile(train_mae_loss, [0.75, 0.25]))
threshold = 3* np.max(train_mae_loss)
idx = np.where(test_mae_loss >threshold)
test_type_7 = pd.DataFrame(test_type_7).reset_index(drop = True)
test_type_7["target"] = 0
test_type_7.loc[idx[0], "target"] = 1
# Out:
# 5/5 [==============================] - 0s 2ms/step
# Reconstruction error threshold:  0.6277671392342657
# ...
# 18/18 [==============================] - 0s 2ms/step

# %%
test_type_7[test_type_7["target"] == 1]
# Out:
#      air_inflow  motor_rpm  motor_temp  motor_current  air_end_temp  \
# 511    0.211712   0.307758    0.308017       0.344960      0.341971
# 517    0.734234   0.898551    0.898734       0.962679      0.932492
# 528    0.157658   0.243393    0.243575       0.277642      0.277532
# 529    0.274775   0.376385    0.376678       0.416812      0.410501
#
#      motor_vibe  out_pressure  air_inflow/motor_rpm  air_inflow/motor_temp  \
# 511    0.461538           0.0            -15.120762               0.232677
# 517    1.053846           0.0            -14.835213               0.703133
# 528    0.392308           0.0            -14.678851               0.171891
# 529    0.530769           0.0            -14.717973               0.303040
#
#      air_inflow/motor_current  ...  \
# 511                -19.411869  ...
# 517                -19.151481  ...
# 528                -19.000951  ...
# 529                -19.052009  ...
#
#      motor_temp/motor_current-motor_temp/motor_vibe  \
# ...

# %%
plt.plot(test_type_7.iloc[510:531,-1])

# %%
plt.plot(test_type_7.iloc[510:531,:21])

# %% [markdown]
# # 제출용 파일 생성

# %%
test_type_0
# Out:
#       air_inflow  motor_rpm  motor_temp  motor_current  air_end_temp  \
# 0       0.614350   0.617572    0.617647       0.617708      0.617657
# 1       0.681614   0.684211    0.684110       0.684028      0.684211
# 2       0.260090   0.259762    0.259740       0.259722      0.259762
# 3       0.475336   0.477504    0.477464       0.477431      0.477419
# 4       0.412556   0.413837    0.413675       0.413889      0.413922
# ...          ...        ...         ...            ...           ...
# 1291    0.067265   0.066638    0.066845       0.066667      0.066553
# 1292    0.905830   0.906621    0.906417       0.906597      0.906621
# 1293    0.040359   0.040323    0.040489       0.040278      0.040407
# 1294    0.017937   0.019949    0.019862       0.020139      0.020034
# 1295    0.556054   0.556452    0.556532       0.556597      0.556537
#
#       motor_vibe  out_pressure  air_inflow/motor_rpm  air_inflow/motor_temp  \
# ...

# %%
a = pd.concat([test_type_0["target"],test_type_1["target"],test_type_2["target"],test_type_3["target"],test_type_4["target"],test_type_5["target"],test_type_6["target"],test_type_7["target"]]).reset_index(drop = True)

# %%
sub = pd.read_csv("/content/drive/MyDrive/이상탐지/answer_sample.csv")

# %%
sub["label"] = a

# %%
sub.to_csv("/content/drive/MyDrive/이상탐지/a_7.csv",index = False)

# %%
a7 = pd.read_csv("/content/drive/MyDrive/이상탐지/a_7.csv")#다쓴거

# %%
a7[a7["label"] == 1]
# Out:
#       type  label
# 585      0      1
# 586      0      1
# 587      0      1
# 588      0      1
# 589      0      1
# ...    ...    ...
# 6800     6      1
# 7342     7      1
# 7348     7      1
# 7359     7      1
# 7360     7      1
#
# [337 rows x 2 columns]

# %%
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
unique, counts = np.unique(a7[a7["label"] == 1]["type"], return_counts=True)

# Create pie chart
fig = go.Figure(data=[go.Pie(labels=unique, values=counts, hole=.3)])

# Update layout
fig.update_layout(title='PREDICTED TEST Label Distribution')

# Show plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
train_type_0["target"] = 0
new_train_data_type_0 = pd.concat([train_type_0,test_type_0[test_type_0["target"] == 1]],axis = 0).reset_index(drop = True)
new_train_data_y = new_train_data_type_0["target"]
new_train_data_x = new_train_data_type_0.drop(["target"],axis =1)
X_train,X_val, y_train,y_val = train_test_split(new_train_data_x,new_train_data_y, test_size=0.2, random_state=RANDOM_SEED)
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=11)
X_train_over, y_train_over = smote.fit_resample(X_train, y_train)

# %% [markdown]
# # 지도 학습 시도 (SMOTE+DNN)

# %%
model = tf.keras.models.Sequential([

  tf.keras.layers.Dense(128, activation='relu'), # 첫 번째 은닉층
  tf.keras.layers.Dense(128, activation='relu'),  # 두 번째 은닉층
  tf.keras.layers.Dense(32, activation='relu'),
  tf.keras.layers.Dense(1, activation='sigmoid') # 출력층
])

# 모델 컴파일
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# 모델 훈련
model.fit(X_train_over, y_train_over, epochs=100, validation_data=(X_val, y_val),callbacks = callbacks)

# 모델 평가
test_loss, test_acc = model.evaluate(X_val, y_val, verbose=2)
print('Test accuracy:', test_acc)
# Out:
# Epoch 1/100
# 22/22 [==============================] - 3s 20ms/step - loss: 0.8129 - accuracy: 0.9451 - val_loss: 0.0088 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 2/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 3/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.0391 - accuracy: 0.9986 - val_loss: 4.2174e-04 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 4/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 5/100
# 22/22 [==============================] - 0s 7ms/step - loss: 7.8611e-04 - accuracy: 1.0000 - val_loss: 5.3021e-04 - val_accuracy: 1.0000 - lr: 9.0000e-04
# Epoch 6/100
# 22/22 [==============================] - 0s 8ms/step - loss: 1.9680e-04 - accuracy: 1.0000 - val_loss: 1.8350e-04 - val_accuracy: 1.0000 - lr: 8.1000e-04
# Epoch 7/100
# ...

# %%
pred = model.predict(test_type_0[test_type_0["target"] == 0].drop(["target"],axis = 1))

def to_binary(y_pred, th = 0.3):
  y_pred_binary = np.zeros_like(y_pred)
  y_pred_binary[y_pred >= th] = 1
  return y_pred_binary
pred_label = to_binary(pred)
test_type_0.loc[test_type_0["target"] == 0, "target"] = pred_label
pred_label.sum()
# Out:
# 37/37 [==============================] - 0s 2ms/step
# 0.0

# %%
train_type_1["target"] = 0
new_train_data_type_1 = pd.concat([train_type_1,test_type_1[test_type_1["target"] == 1]]).reset_index(drop = True)
new_train_data_y = new_train_data_type_1["target"]
new_train_data_x = new_train_data_type_1.iloc[:,:-1]
X_train,X_val, y_train,y_val = train_test_split(new_train_data_x,new_train_data_y, test_size=0.2, random_state=RANDOM_SEED)

model = tf.keras.models.Sequential([

  tf.keras.layers.Dense(128, activation='relu'), # 첫 번째 은닉층
  tf.keras.layers.Dense(128, activation='relu'),  # 두 번째 은닉층
  tf.keras.layers.Dense(32, activation='relu'),
  tf.keras.layers.Dense(1, activation='sigmoid') # 출력층
])

# 모델 컴파일
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# 모델 훈련
model.fit(X_train, y_train, epochs=100, validation_data=(X_val, y_val),callbacks = callbacks)

# 모델 평가
test_loss, test_acc = model.evaluate(X_val, y_val, verbose=2)
print('Test accuracy:', test_acc)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 2s 26ms/step - loss: 0.3736 - accuracy: 0.8034 - val_loss: 0.0234 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 2/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 4.7760e-04 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 3/100
# 10/10 [==============================] - 0s 7ms/step - loss: 2.6388e-04 - accuracy: 1.0000 - val_loss: 4.9246e-05 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 4/100
# 10/10 [==============================] - 0s 10ms/step - loss: 4.6161e-05 - accuracy: 1.0000 - val_loss: 1.7003e-05 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 5/100
# 10/10 [==============================] - 0s 8ms/step - loss: 2.2989e-05 - accuracy: 1.0000 - val_loss: 1.0997e-05 - val_accuracy: 1.0000 - lr: 9.0000e-04
# Epoch 6/100
# 10/10 [==============================] - 0s 8ms/step - loss: 1.6906e-05 - accuracy: 1.0000 - val_loss: 8.9969e-06 - val_accuracy: 1.0000 - lr: 8.1000e-04
# ...

# %%
pred = model.predict(test_type_1[test_type_1["target"] == 0].drop(["target"],axis = 1))

def to_binary(y_pred, th = 0.3):
  y_pred_binary = np.zeros_like(y_pred)
  y_pred_binary[y_pred >= th] = 1
  return y_pred_binary
pred_label = to_binary(pred)
test_type_1.loc[test_type_1["target"] == 0, "target"] = pred_label
pred_label.sum()
# Out:
# 35/35 [==============================] - 0s 2ms/step
# 0.0

# %%
train_type_2["target"] = 0
new_train_data_type_2 = pd.concat([train_type_2,test_type_2[test_type_2["target"] == 1]]).reset_index(drop = True)
new_train_data_y = new_train_data_type_2["target"]
new_train_data_x = new_train_data_type_2.iloc[:,:-1]
X_train,X_val, y_train,y_val = train_test_split(new_train_data_x,new_train_data_y, test_size=0.2, random_state=RANDOM_SEED)

model = tf.keras.models.Sequential([

  tf.keras.layers.Dense(128, activation='relu'), # 첫 번째 은닉층
  tf.keras.layers.Dense(128, activation='relu'),  # 두 번째 은닉층
  tf.keras.layers.Dense(32, activation='relu'),
  tf.keras.layers.Dense(1, activation='sigmoid') # 출력층
])

# 모델 컴파일
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# 모델 훈련
model.fit(X_train, y_train, epochs=100, validation_data=(X_val, y_val),callbacks = callbacks)

# 모델 평가
test_loss, test_acc = model.evaluate(X_val, y_val, verbose=2)
print('Test accuracy:', test_acc)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 2s 27ms/step - loss: 0.6302 - accuracy: 0.8917 - val_loss: 0.2503 - val_accuracy: 0.9873 - lr: 0.0010
# Epoch 2/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1560 - accuracy: 0.9968 - val_loss: 0.0499 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 3/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0223 - accuracy: 1.0000 - val_loss: 0.0147 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 4/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 5/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0067 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 6/100
# 10/10 [==============================] - 0s 10ms/step - loss: 9.0064e-04 - accuracy: 1.0000 - val_loss: 0.0071 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 7/100
# ...

# %%
pred = model.predict(test_type_2[test_type_2["target"] == 0].drop(["target"],axis = 1))

def to_binary(y_pred, th = 0.3):
  y_pred_binary = np.zeros_like(y_pred)
  y_pred_binary[y_pred >= th] = 1
  return y_pred_binary
pred_label = to_binary(pred)
test_type_2.loc[test_type_2["target"] == 0, "target"] = pred_label
pred_label.sum()
# Out:
# 34/34 [==============================] - 0s 2ms/step
# 0.0

# %%
train_type_3["target"] = 0
new_train_data_type_3 = pd.concat([train_type_3,test_type_3[test_type_3["target"] == 1]]).reset_index(drop = True)
new_train_data_y = new_train_data_type_3["target"]
new_train_data_x = new_train_data_type_3.iloc[:,:-1]
X_train,X_val, y_train,y_val = train_test_split(new_train_data_x,new_train_data_y, test_size=0.2, random_state=RANDOM_SEED)
smote = SMOTE(random_state=11)
X_train_over, y_train_over = smote.fit_resample(X_train, y_train)
model = tf.keras.models.Sequential([

  tf.keras.layers.Dense(128, activation='relu'), # 첫 번째 은닉층
  tf.keras.layers.Dense(128, activation='relu'),  # 두 번째 은닉층
  tf.keras.layers.Dense(32, activation='relu'),
  tf.keras.layers.Dense(1, activation='sigmoid') # 출력층
])

# 모델 컴파일
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# 모델 훈련
model.fit(X_train_over, y_train_over, epochs=100, validation_data=(X_val, y_val),callbacks = callbacks)

# 모델 평가
test_loss, test_acc = model.evaluate(X_val, y_val, verbose=2)
print('Test accuracy:', test_acc)
# Out:
# Epoch 1/100
# 16/16 [==============================] - 2s 25ms/step - loss: 0.4099 - accuracy: 0.9488 - val_loss: 0.0168 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 2/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 3/100
# 16/16 [==============================] - 0s 9ms/step - loss: 3.7230e-04 - accuracy: 1.0000 - val_loss: 4.2654e-04 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 4/100
# 16/16 [==============================] - 0s 9ms/step - loss: 1.7798e-04 - accuracy: 1.0000 - val_loss: 2.5129e-04 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 5/100
# 16/16 [==============================] - 0s 10ms/step - loss: 1.1266e-04 - accuracy: 1.0000 - val_loss: 1.7765e-04 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 6/100
# 16/16 [==============================] - 0s 9ms/step - loss: 8.2406e-05 - accuracy: 1.0000 - val_loss: 1.3508e-04 - val_accuracy: 1.0000 - lr: 9.0000e-04
# Epoch 7/100
# ...

# %%
pred = model.predict(test_type_3[test_type_3["target"] == 0].drop(["target"],axis = 1))

def to_binary(y_pred, th = 0.3):
  y_pred_binary = np.zeros_like(y_pred)
  y_pred_binary[y_pred >= th] = 1
  return y_pred_binary
pred_label = to_binary(pred)
test_type_3.loc[test_type_3["target"] == 0, "target"] = pred_label
pred_label.sum()
# Out:
# 28/28 [==============================] - 0s 2ms/step
# 0.0

# %%
train_type_4["target"] = 0
new_train_data_type_4 = pd.concat([train_type_4,test_type_4[test_type_4["target"] == 1]]).reset_index(drop = True)
new_train_data_y = new_train_data_type_4["target"]
new_train_data_x = new_train_data_type_4.iloc[:,:-1]
X_train,X_val, y_train,y_val = train_test_split(new_train_data_x,new_train_data_y, test_size=0.2, random_state=RANDOM_SEED)

model = tf.keras.models.Sequential([

  tf.keras.layers.Dense(128, activation='relu'), # 첫 번째 은닉층
  tf.keras.layers.Dense(128, activation='relu'),  # 두 번째 은닉층
  tf.keras.layers.Dense(32, activation='relu'),
  tf.keras.layers.Dense(1, activation='sigmoid') # 출력층
])

# 모델 컴파일
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# 모델 훈련
model.fit(X_train, y_train, epochs=100, validation_data=(X_val, y_val),callbacks = callbacks)

# 모델 평가
test_loss, test_acc = model.evaluate(X_val, y_val, verbose=2)
print('Test accuracy:', test_acc)
# Out:
# Epoch 1/100
# 8/8 [==============================] - 2s 32ms/step - loss: 0.5051 - accuracy: 0.8715 - val_loss: 0.2032 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 2/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.1148 - accuracy: 0.9960 - val_loss: 0.0340 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 3/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0226 - accuracy: 0.9960 - val_loss: 0.0044 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 4/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 5/100
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 6.8570e-04 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 6/100
# 8/8 [==============================] - 0s 10ms/step - loss: 5.5947e-04 - accuracy: 1.0000 - val_loss: 3.7854e-04 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 7/100
# ...

# %%
pred = model.predict(test_type_4[test_type_4["target"] == 0].drop(["target"],axis = 1))

def to_binary(y_pred, th = 0.3):
  y_pred_binary = np.zeros_like(y_pred)
  y_pred_binary[y_pred >= th] = 1
  return y_pred_binary
pred_label = to_binary(pred)
test_type_4.loc[test_type_4["target"] == 0, "target"] = pred_label
pred_label.sum()
# Out:
# 29/29 [==============================] - 0s 2ms/step
# 0.0

# %%
train_type_5["target"] = 0
new_train_data_type_5 = pd.concat([train_type_5,test_type_5[test_type_5["target"] == 1]]).reset_index(drop = True)
new_train_data_y = new_train_data_type_5["target"]
new_train_data_x = new_train_data_type_5.iloc[:,:-1]
X_train,X_val, y_train,y_val = train_test_split(new_train_data_x,new_train_data_y, test_size=0.2, random_state=RANDOM_SEED)

model = tf.keras.models.Sequential([

  tf.keras.layers.Dense(128, activation='relu'), # 첫 번째 은닉층
  tf.keras.layers.Dense(128, activation='relu'),  # 두 번째 은닉층
  tf.keras.layers.Dense(32, activation='relu'),
  tf.keras.layers.Dense(1, activation='sigmoid') # 출력층
])

# 모델 컴파일
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# 모델 훈련
model.fit(X_train, y_train, epochs=100, validation_data=(X_val, y_val),callbacks = callbacks)

# 모델 평가
test_loss, test_acc = model.evaluate(X_val, y_val, verbose=2)
print('Test accuracy:', test_acc)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 2s 36ms/step - loss: 0.3534 - accuracy: 0.9910 - val_loss: 0.1477 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 2/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0792 - accuracy: 1.0000 - val_loss: 0.0198 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 3/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 4/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 8.2060e-04 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 5/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 9.8317e-04 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 6/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 9.5079e-04 - val_accuracy: 1.0000 - lr: 9.0000e-04
# Epoch 7/100
# ...

# %%
pred = model.predict(test_type_5[test_type_5["target"] == 0].drop(["target"],axis = 1))

def to_binary(y_pred, th = 0.3):
  y_pred_binary = np.zeros_like(y_pred)
  y_pred_binary[y_pred >= th] = 1
  return y_pred_binary
pred_label = to_binary(pred)
test_type_5.loc[test_type_5["target"] == 0, "target"] = pred_label
pred_label.sum()
# Out:
# 23/23 [==============================] - 0s 3ms/step
# 0.0

# %%
train_type_6["target"] = 0
new_train_data_type_6 = pd.concat([train_type_6,test_type_6[test_type_6["target"] == 1]]).reset_index(drop = True)
new_train_data_y = new_train_data_type_6["target"]
new_train_data_x = new_train_data_type_6.iloc[:,:-1]
X_train,X_val, y_train,y_val = train_test_split(new_train_data_x,new_train_data_y, test_size=0.2, random_state=RANDOM_SEED)
smote = SMOTE(random_state=11)
X_train_over, y_train_over = smote.fit_resample(X_train, y_train)
model = tf.keras.models.Sequential([

  tf.keras.layers.Dense(128, activation='relu'), # 첫 번째 은닉층
  tf.keras.layers.Dense(128, activation='relu'),  # 두 번째 은닉층
  tf.keras.layers.Dense(32, activation='relu'),
  tf.keras.layers.Dense(1, activation='sigmoid') # 출력층
])

# 모델 컴파일
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# 모델 훈련
model.fit(X_train_over, y_train_over, epochs=100, validation_data=(X_val, y_val),callbacks = callbacks)

# 모델 평가
test_loss, test_acc = model.evaluate(X_val, y_val, verbose=2)
print('Test accuracy:', test_acc)
# Out:
# Epoch 1/100
# 13/13 [==============================] - 2s 20ms/step - loss: 0.4014 - accuracy: 0.9492 - val_loss: 0.0601 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 2/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0169 - accuracy: 1.0000 - val_loss: 0.0059 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 3/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 9.8785e-04 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 4/100
# 13/13 [==============================] - 0s 6ms/step - loss: 3.0482e-04 - accuracy: 1.0000 - val_loss: 2.4410e-04 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 5/100
# 13/13 [==============================] - 0s 6ms/step - loss: 9.7120e-05 - accuracy: 1.0000 - val_loss: 1.1085e-04 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 6/100
# 13/13 [==============================] - 0s 7ms/step - loss: 4.6036e-05 - accuracy: 1.0000 - val_loss: 5.8473e-05 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 7/100
# ...

# %%
pred = model.predict(test_type_6[test_type_6["target"] == 0].drop(["target"],axis = 1))

def to_binary(y_pred, th = 0.3):
  y_pred_binary = np.zeros_like(y_pred)
  y_pred_binary[y_pred >= th] = 1
  return y_pred_binary
pred_label = to_binary(pred)
test_type_6.loc[test_type_6["target"] == 0, "target"] = pred_label
pred_label.sum()
# Out:
# 21/21 [==============================] - 0s 3ms/step
# 0.0

# %%
train_type_7["target"] = 0
new_train_data_type_7 = pd.concat([train_type_7,test_type_7[test_type_7["target"] == 1]]).reset_index(drop = True)
new_train_data_y = new_train_data_type_7["target"]
new_train_data_x = new_train_data_type_7.iloc[:,:-1]
X_train,X_val, y_train,y_val = train_test_split(new_train_data_x,new_train_data_y, test_size=0.2, random_state=RANDOM_SEED)

model = tf.keras.models.Sequential([

  tf.keras.layers.Dense(128, activation='relu'), # 첫 번째 은닉층
  tf.keras.layers.Dense(128, activation='relu'),  # 두 번째 은닉층
  tf.keras.layers.Dense(32, activation='relu'),
  tf.keras.layers.Dense(1, activation='sigmoid') # 출력층
])

# 모델 컴파일
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# 모델 훈련
model.fit(X_train, y_train, epochs=100, validation_data=(X_val, y_val),callbacks = callbacks)

# 모델 평가
test_loss, test_acc = model.evaluate(X_val, y_val, verbose=2)
print('Test accuracy:', test_acc)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 3s 55ms/step - loss: 0.5224 - accuracy: 0.8289 - val_loss: 0.3054 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 2/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.1822 - accuracy: 1.0000 - val_loss: 0.0700 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 3/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0364 - accuracy: 1.0000 - val_loss: 0.0131 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 4/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 5/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 6/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 9.6645e-04 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 7/100
# ...

# %%
pred = model.predict(test_type_7[test_type_7["target"] == 0].drop(["target"],axis = 1))

def to_binary(y_pred, th = 0.3):
  y_pred_binary = np.zeros_like(y_pred)
  y_pred_binary[y_pred >= th] = 1
  return y_pred_binary
pred_label = to_binary(pred)
test_type_7.loc[test_type_7["target"] == 0, "target"] = pred_label
pred_label.sum()
# Out:
# 18/18 [==============================] - 0s 1ms/step
# 0.0

# %%
a = pd.concat([test_type_0["target"],test_type_1["target"],test_type_2["target"],
              test_type_3["target"],test_type_4["target"],
              test_type_5["target"],test_type_6["target"],test_type_7["target"]]).reset_index(drop = True)

# %%
sub['label'] = a

# %%
sub.to_csv("/content/drive/MyDrive/이상탐지/a_8.csv",index = False)
